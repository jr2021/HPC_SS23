# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.animation as animation
from loguru import logger
from tqdm import tqdm

from Simulation import Simulation

# %% [markdown]
# # Milestone 0 (Explosion)

# %%
sim = Simulation(
    nx=20,
    ny=20,
    scenario='explosion',
    epsilon=0.5,
    omega=1,
    T=25
)

sim.run()
sim.animation()
# Out:
# t=: 100%|██████████| 25/25 [00:00<00:00, 1471.07it/s]

# %% [markdown]
# # Milestone 3 (Shear Wave Decay)

# %%
sim = Simulation(
    nx=50,
    ny=100,
    scenario='shear_wave_velocity',
    epsilon=0.05,
    omega=0.5,
    T=2000
)

sim.run()
sim.plot_sin_over_time()
sim.plot_amplitude_over_time()
# Out:
# ...
# t=: 100%|██████████| 2000/2000 [00:02<00:00, 710.34it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Milestone 4 (Couette Flow)

# %%
sim = Simulation(
    nx=50,
    ny=100,
    scenario='couette_flow',
    omega=0.1,
    T=2000,
)

sim.run()
sim.plot_couette_flow_over_time()
# Out:
# t=: 100%|██████████| 2000/2000 [00:02<00:00, 734.53it/s]
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Milestone 5 (Poiseuille Flow)

# %%
sim = Simulation(
    nx=50,
    ny=100,
    scenario='poiseuille_flow',
    omega=0.3,
    T=100
)

sim.run()
# Out:
# t=: 100%|██████████| 100/100 [00:00<00:00, 185.39it/s]

# %% [markdown]
# ## Milestone 6 (Sliding Lid)

# %%
sim = Simulation(
    nx=300,
    ny=300,
    scenario='sliding_lid',
    omega=0.5,
    T=1000
)

sim.run()
sim.plot_final_velocity_field()
# Out:
# t=: 100%|██████████| 1000/1000 [00:22<00:00, 44.42it/s]

# %%
fig, ax = plt.subplots()

np = [1, 4, 9, 16, 25]
time = [24.16]
